# %% [markdown]
# # A variety of visualizations used in the report, presentation, and GitHub readme

# %%
# from google.colab import drive
# drive.mount("mnt")

# %cd "mnt/My Drive/Colab Notebooks/adversarial_examples/results"

# !pip install import-ipynb
# import import_ipynb

# %%
import pandas as pd
import numpy as np
import os
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# # GitHub Visualizations: An example of analyzing output from one image

# %%
# %pwd
# %cd "results"
# %cd "CIFAR10"
# %cd "WideResNet2810"
# Out:
# /Users/jaredratto/Library/CloudStorage/GoogleDrive-jared.ratto@gmail.com/My Drive/Colab Notebooks/adversarial_examples/results
# /Users/jaredratto/Library/CloudStorage/GoogleDrive-jared.ratto@gmail.com/My Drive/Colab Notebooks/adversarial_examples/results/CIFAR10
# /Users/jaredratto/Library/CloudStorage/GoogleDrive-jared.ratto@gmail.com/My Drive/Colab Notebooks/adversarial_examples/results/CIFAR10/WideResNet2810

# %%
result_dict = np.load('0_10.npy',allow_pickle=True)
result_dict = np.expand_dims(result_dict,axis=0)[0]

# %%
print("How many solutions in the global pareto front?",len(result_dict["adversarial_labels"]))
print("What were the predicted lables?",result_dict["adversarial_labels"])
print("What was the true label?",result_dict["true_label"])

l0_temp_list = []
linf_temp_list = []
for i in result_dict['front0_fitness']:
  l0_temp_list.append(i[1])
  linf_temp_list.append(i[2][0])
print("What were the l_0 norms?",l0_temp_list)
print("What were the l_inf norms?",linf_temp_list)
# Out:
# How many solutions in the global pareto front? 20
# What were the predicted lables? [4, 5, 5, 4, 4, 4, 4, 4, 4, 4, 2, 4, 8, 4, 4, 4, 9, 9, 9, 9]
# What was the true label? 0
# What were the l_0 norms? [554, 401, 317, 305, 271, 197, 170, 150, 148, 141, 136, 134, 124, 119, 118, 107, 102, 99, 96, 95]
# What were the l_inf norms? [0.04897884311947091, 0.05180344424882515, 0.05354178205812336, 0.06950695254482549, 0.07035657549769436, 0.08561226842646807, 0.0886305469913575, 0.11285592150800199, 0.14639348265530652, 0.16189450725494067, 0.1637691548183408, 0.20149687649428988, 0.21141788963473462, 0.21341997450951167, 0.21697658417907828, 0.22457844279797723, 0.28171084129849366, 0.3405610259736322, 0.3563692817480328, 0.39521865752952057]

# %%
class_dictionary = {0:"Airplane",
                   1:"Car",
                   2:"Bird",
                   3:"Cat",
                   4:"Deer",
                   5:"Dog",
                   6:"Frog",
                   7:"Horse",
                   8:"Ship",
                   9:"Truck"}
class_list = []
for i in result_dict["adversarial_labels"]:
    class_list.append(class_dictionary[i])
true_class = class_dictionary[int(result_dict["true_label"])]

# %%
fig, ax = plt.subplots(2, 10, figsize=(20, 4))

# I think I could do this much better with a loop. But its tricky because I think the fig size is better if its completely filled
# So maybe only do this for particular illustration purposes

ax[0,0].imshow(result_dict['front0_imgs'][0], interpolation='nearest')
ax[0,0].set_title(class_list[0])
ax[0,0].set_xlabel("{l0} pixels {linf} intensity".format(l0 = l0_temp_list[0],linf = round(linf_temp_list[0],3)))
ax[0,1].imshow(result_dict['front0_imgs'][1], interpolation='nearest')
ax[0,1].set_title(class_list[1])
ax[0,1].set_xlabel("{l0} pixels {linf} intensity".format(l0 = l0_temp_list[1],linf = round(linf_temp_list[1],3)))
ax[0,2].imshow(result_dict['front0_imgs'][2], interpolation='nearest')
ax[0,2].set_title(class_list[2])
ax[0,2].set_xlabel("{l0} pixels {linf} intensity".format(l0 = l0_temp_list[2],linf = round(linf_temp_list[2],3)))
ax[0,3].imshow(result_dict['front0_imgs'][3], interpolation='nearest')
ax[0,3].set_title(class_list[3])
ax[0,3].set_xlabel("{l0} pixels {linf} intensity".format(l0 = l0_temp_list[3],linf = round(linf_temp_list[3],3)))
ax[0,4].imshow(result_dict['front0_imgs'][4], interpolation='nearest')
ax[0,4].set_title(class_list[4])
ax[0,4].set_xlabel("{l0} pixels {linf} intensity".format(l0 = l0_temp_list[4],linf = round(linf_temp_list[4],3)))
ax[0,5].imshow(result_dict['front0_imgs'][5], interpolation='nearest')
ax[0,5].set_title(class_list[5])
ax[0,5].set_xlabel("{l0} pixels {linf} intensity".format(l0 = l0_temp_list[5],linf = round(linf_temp_list[5],3)))
ax[0,6].imshow(result_dict['front0_imgs'][6], interpolation='nearest')
ax[0,6].set_title(class_list[6])
ax[0,6].set_xlabel("{l0} pixels {linf} intensity".format(l0 = l0_temp_list[6],linf = round(linf_temp_list[6],3)))
ax[0,7].imshow(result_dict['front0_imgs'][7], interpolation='nearest')
ax[0,7].set_title(class_list[7])
ax[0,7].set_xlabel("{l0} pixels {linf} intensity".format(l0 = l0_temp_list[7],linf = round(linf_temp_list[7],3)))
ax[0,8].imshow(result_dict['front0_imgs'][8], interpolation='nearest')
ax[0,8].set_title(class_list[8])
ax[0,8].set_xlabel("{l0} pixels {linf} intensity".format(l0 = l0_temp_list[8],linf = round(linf_temp_list[8],3)))
ax[0,9].imshow(result_dict['front0_imgs'][9], interpolation='nearest')
ax[0,9].set_title(class_list[9])
ax[0,9].set_xlabel("{l0} pixels {linf} intensity".format(l0 = l0_temp_list[9],linf = round(linf_temp_list[9],3)))

ax[1,0].imshow(result_dict['front0_imgs'][10], interpolation='nearest')
ax[1,0].set_title(class_list[10])
ax[1,0].set_xlabel("{l0} pixels {linf} intensity".format(l0 = l0_temp_list[10],linf = round(linf_temp_list[10],3)))
ax[1,1].imshow(result_dict['front0_imgs'][11], interpolation='nearest')
ax[1,1].set_title(class_list[11])
ax[1,1].set_xlabel("{l0} pixels {linf} intensity".format(l0 = l0_temp_list[11],linf = round(linf_temp_list[11],3)))
ax[1,2].imshow(result_dict['front0_imgs'][12], interpolation='nearest')
ax[1,2].set_title(class_list[12])
ax[1,2].set_xlabel("{l0} pixels {linf} intensity".format(l0 = l0_temp_list[12],linf = round(linf_temp_list[12],3)))
ax[1,3].imshow(result_dict['front0_imgs'][13], interpolation='nearest')
ax[1,3].set_title(class_list[13])
ax[1,3].set_xlabel("{l0} pixels {linf} intensity".format(l0 = l0_temp_list[13],linf = round(linf_temp_list[13],3)))
ax[1,4].imshow(result_dict['front0_imgs'][14], interpolation='nearest')
ax[1,4].set_title(class_list[14])
ax[1,4].set_xlabel("{l0} pixels {linf} intensity".format(l0 = l0_temp_list[14],linf = round(linf_temp_list[14],3)))
ax[1,5].imshow(result_dict['front0_imgs'][15], interpolation='nearest')
ax[1,5].set_title(class_list[15])
ax[1,5].set_xlabel("{l0} pixels {linf} intensity".format(l0 = l0_temp_list[15],linf = round(linf_temp_list[15],3)))
ax[1,6].imshow(result_dict['front0_imgs'][16], interpolation='nearest')
ax[1,6].set_title(class_list[16])
ax[1,6].set_xlabel("{l0} pixels {linf} intensity".format(l0 = l0_temp_list[16],linf = round(linf_temp_list[16],3)))
ax[1,7].imshow(result_dict['front0_imgs'][17], interpolation='nearest')
ax[1,7].set_title(class_list[17])
ax[1,7].set_xlabel("{l0} pixels {linf} intensity".format(l0 = l0_temp_list[17],linf = round(linf_temp_list[17],3)))
ax[1,8].imshow(result_dict['front0_imgs'][18], interpolation='nearest')
ax[1,8].set_title(class_list[18])
ax[1,8].set_xlabel("{l0} pixels {linf} intensity".format(l0 = l0_temp_list[18],linf = round(linf_temp_list[18],3)))
ax[1,9].imshow(result_dict['front0_imgs'][19], interpolation='nearest')
ax[1,9].set_title(class_list[19])
ax[1,9].set_xlabel("{l0} pixels {linf} intensity".format(l0 = l0_temp_list[19],linf = round(linf_temp_list[19],3)))

fig.suptitle(true_class, fontsize=25)

plt.tight_layout()
# plt.savefig("set_of_images_jetplane")
plt.show()

# %%
# The Pareto Front

l0_array = np.asarray(l0_temp_list)
linf_array = np.asarray(linf_temp_list)
l0_array = l0_array/1024

plt.figure(figsize=(6,6))

plt.scatter(linf_array,l0_array,color="orangered")
plt.xlim(0,0.6)
plt.ylim(0,0.6)

plt.xlabel(r'$\ell_\infty- norm$',labelpad=20,size=16)
plt.ylabel(r'$\ell_0- norm$',labelpad=20,size=16)

plt.title("Pareto Front",pad=15,size=20)

plt.grid()

plt.tight_layout()
# plt.savefig("pareto_front_jetplane")
plt.show()

# %% [markdown]
# # A class's aggregate curve, averaged over pareto curves from all images of the same class

# %%
# Loop for all CIFAR10 classes
length = 200
standard_x_coords = np.empty((0,length))
standard_y_coords = np.empty((0,length))
# Do this for each of the 10 CIFAR classes
for selected_class in range(10):
  # Resetting variables
  selected_class = str(selected_class)
  l0 = np.empty(0)
  linf = np.empty(0)
  label = 0
  img_labels = np.empty(0)

  # Gather all the files of an individual class and append the arrays of l0, linf, and img_labels. Combine these into the array a.
  for i in os.listdir():
    if i[0] == selected_class:
      # individual output file level
      temp_dict = np.load(i,allow_pickle=True)
      temp_dict = np.expand_dims(temp_dict,axis=0)[0]
      for j in temp_dict['front0_fitness']:
        l0 = np.append(l0,(j[1]))
        linf = np.append(linf,(j[2][0]))
      img_labels = np.append(img_labels,np.ones(len(temp_dict['front0_fitness'])) * label )
      label+=1
  l0 = l0/1024
  a = np.hstack((linf.reshape((-1,1)),l0.reshape((-1,1)))).copy()

  # x and y array are the arrays of interpolated x and y coordinates for the fronts of an individual class
  x_array = np.empty((0,length))
  y_array = np.empty((0,length))
  # loop: the interpolation of individual fronts within a class, and then averaging them
  for i in range(max((img_labels).astype(int))):
    a_i = a[img_labels==i].copy()
    min_a_x, max_a_x = min(a_i[:,0]), max(a_i[:,0])
    new_a_x = np.linspace(min_a_x, max_a_x, length).reshape((1,length))
    new_a_y = np.interp(new_a_x, a_i[:,0], a_i[:,1]).reshape((1,length))

    x_array = np.vstack((x_array,new_a_x))
    y_array = np.vstack((y_array,new_a_y))
  # taking each "average front" and then forming the 2 grand arrays for the 10 classes
  standard_x_coords = np.vstack((standard_x_coords,np.mean(x_array,axis=0)))
  standard_y_coords = np.vstack((standard_y_coords,np.mean(y_array,axis=0)))

# %%
l0 = np.empty(0)
linf = np.empty(0)
color_label = np.empty(0)
cl=0
for i in os.listdir():
    if i[0] == "9": # truck
        temp_dict = np.load(i,allow_pickle=True)
        temp_dict = np.expand_dims(temp_dict,axis=0)[0] 
        
        for j in temp_dict['front0_fitness']:
            l0 = np.append(l0,(j[1]))
            linf = np.append(linf,(j[2][0]))
            color_label = np.append(color_label,cl)
        cl+=1
l0 = l0/1024

# %%
# for the truck class
plt.figure(figsize=(8,8))
plt.plot(standard_x_coords[9],standard_y_coords[9], '-o',linewidth=4, color='blue')
plt.scatter(linf,l0,c=color_label,cmap='Dark2')
plt.xlim(0,0.6)
plt.ylim(0,0.6)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)
plt.xlabel(r'$\ell_\infty- norm$',labelpad=20,size=20)
plt.ylabel(r'$\ell_0- norm$',labelpad=20,size=20)
plt.title("Truck",pad=15,size=24)
plt.grid()
plt.savefig("trucks.png")
plt.show()

# %% [markdown]
# # Show the average pareto fronts for all classes, within a single network

# %%
plt.figure(figsize=(8,8))
color_list = ['navy','orange','mediumaquamarine','red','violet','deepskyblue','purple','dimgray','olive','saddlebrown']
for j in range(10):
    plt.plot(standard_x_coords[j],standard_y_coords[j],color=color_list[j],linewidth=2.5,label = class_dictionary[j])
#     plt.plot(standard_x_coords[j],standard_y_coords[j],linewidth=2.5,color=(np.ones(200)*j).astype(int),cmap='Accent',label = class_dictionary[j])
plt.xlim(0,0.6)
plt.ylim(0,0.6)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)
plt.xlabel(r'$\ell_\infty- norm$',labelpad=20,size=20)
plt.ylabel(r'$\ell_0- norm$',labelpad=20,size=20)
plt.title("Average Pareto Fronts",pad=15,size=24)
plt.legend(fontsize="14",loc='upper right')
plt.grid()
plt.savefig("all_classes.png")
plt.show()

# %% [markdown]
# # Adversarially trained network: show an average curve from multiple pareto curves

# %%
# %pwd
# %cd ..
# %cd "WideResNet_defended"
# Out:
# /Users/jaredratto/Library/CloudStorage/GoogleDrive-jared.ratto@gmail.com/My Drive/Colab Notebooks/adversarial_examples/results/CIFAR10
# /Users/jaredratto/Library/CloudStorage/GoogleDrive-jared.ratto@gmail.com/My Drive/Colab Notebooks/adversarial_examples/results/CIFAR10/WideResNet_defended

# %%
# %pwd
# Out:
# '/Users/jaredratto/Library/CloudStorage/GoogleDrive-jared.ratto@gmail.com/My Drive/Colab Notebooks/adversarial_examples/results/CIFAR10/WideResNet_defended'

# %%
length = 200
defend_x_coords = np.empty((0,length))
defend_y_coords = np.empty((0,length))
# Do this for each of the 10 CIFAR classes
for selected_class in range(10):
  # Resetting variables
  selected_class = str(selected_class)
  l0 = np.empty(0)
  linf = np.empty(0)
  label = 0
  img_labels = np.empty(0)

  # Gather all the files of an individual class and append the arrays of l0, linf, and img_labels. Combine these into the array a.
  for i in os.listdir():
    if i[0] == selected_class:
      # individual output file level
      temp_dict = np.load(i,allow_pickle=True)
      temp_dict = np.expand_dims(temp_dict,axis=0)[0]
      for j in temp_dict['front0_fitness']:
        l0 = np.append(l0,(j[1]))
        linf = np.append(linf,(j[2][0]))
      img_labels = np.append(img_labels,np.ones(len(temp_dict['front0_fitness'])) * label )
      label+=1
  l0 = l0/1024
  a = np.hstack((linf.reshape((-1,1)),l0.reshape((-1,1)))).copy()

  # x and y array are the arrays of interpolated x and y coordinates for the fronts of an individual class
  x_array = np.empty((0,length))
  y_array = np.empty((0,length))
  # loop: the interpolation of individual fronts within a class, and then averaging them
  for i in range(max((img_labels).astype(int))):
    a_i = a[img_labels==i].copy()
    min_a_x, max_a_x = min(a_i[:,0]), max(a_i[:,0])
    new_a_x = np.linspace(min_a_x, max_a_x, length).reshape((1,length))
    new_a_y = np.interp(new_a_x, a_i[:,0], a_i[:,1]).reshape((1,length))

    x_array = np.vstack((x_array,new_a_x))
    y_array = np.vstack((y_array,new_a_y))
  # taking each "average front" and then forming the 2 grand arrays for the 10 classes
  defend_x_coords = np.vstack((defend_x_coords,np.mean(x_array,axis=0)))
  defend_y_coords = np.vstack((defend_y_coords,np.mean(y_array,axis=0)))

# %%
# Try this one out
l0 = np.empty(0)
linf = np.empty(0)
color_label = np.empty(0)
cl=0
for i in os.listdir():
    if i[0] == "9": # truck
        temp_dict = np.load(i,allow_pickle=True)
        temp_dict = np.expand_dims(temp_dict,axis=0)[0] 
        
        for j in temp_dict['front0_fitness']:
            l0 = np.append(l0,(j[1]))
            linf = np.append(linf,(j[2][0]))
            color_label = np.append(color_label,cl)
        cl+=1
l0 = l0/1024

# %%
# truck
plt.figure(figsize=(8,8))
plt.plot(defend_x_coords[9],defend_y_coords[9], '-o',linewidth=4, color='blue')
plt.scatter(linf,l0,c=color_label,cmap='Dark2')
plt.xlim(0,0.6)
plt.ylim(0,0.6)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)
plt.xlabel(r'$\ell_\infty- norm$',labelpad=20,size=20)
plt.ylabel(r'$\ell_0- norm$',labelpad=20,size=20)
plt.title("Truck",pad=15,size=24)
plt.grid()
plt.savefig("trucks.png")
plt.show()

# %% [markdown]
# # Compare a class from a standard network to a defended network

# %%
plt.figure(figsize=(8,8))

plt.plot(standard_x_coords[5],standard_y_coords[5],linewidth=2.5,label = "Standard")
plt.plot(defend_x_coords[5],defend_y_coords[5],linewidth=2.5,label = "Defended")

plt.xlim(0,0.6)
plt.ylim(0,0.6)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)
plt.xlabel(r'$\ell_\infty- norm$',labelpad=20,size=20)
plt.ylabel(r'$\ell_0- norm$',labelpad=20,size=20)
plt.title("Dog",pad=15,size=24)
plt.legend(fontsize="14",loc='upper right')
plt.grid()
# plt.savefig("dog_defend.png")
plt.show()

print("Trained with",np.round(np.mean(defend_x_coords[5]-standard_x_coords[5]),decimals=2),"l_infinity perturbed images")
print("Trained with",np.round(np.mean(defend_y_coords[5]-standard_y_coords[5]),decimals=2),"l_0 perturbed images")
# Out:
# Trained with 0.12 l_infinity perturbed images
# Trained with 0.1 l_0 perturbed images

# %%
plt.figure(figsize=(8,8))

plt.plot(standard_x_coords[0],standard_y_coords[0],linewidth=2.5,label = "Standard")
plt.plot(defend_x_coords[0],defend_y_coords[0],linewidth=2.5,label = "Defended")

plt.xlim(0,0.6)
plt.ylim(0,0.6)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)
plt.xlabel(r'$\ell_\infty- norm$',labelpad=20,size=20)
plt.ylabel(r'$\ell_0- norm$',labelpad=20,size=20)
plt.title("Airplane",pad=15,size=24)
plt.legend(fontsize="14",loc='upper right')
plt.grid()
# plt.savefig("airplane_defend.png")
plt.show()

print("Trained with",np.round(np.mean(defend_x_coords[0]-standard_x_coords[0]),decimals=2),"l_infinity perturbed images")
print("Trained with",np.round(np.mean(defend_y_coords[0]-standard_y_coords[0]),decimals=2),"l_0 perturbed images")
# Out:
# Trained with 0.21 l_infinity perturbed images
# Trained with 0.08 l_0 perturbed images

# %%
plt.figure(figsize=(8,8))

plt.plot(standard_x_coords[6],standard_y_coords[6],linewidth=2.5,label = "Standard")
plt.plot(defend_x_coords[6],defend_y_coords[6],linewidth=2.5,label = "Defended")

plt.xlim(0,0.6)
plt.ylim(0,0.6)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)
plt.xlabel(r'$\ell_\infty- norm$',labelpad=20,size=20)
plt.ylabel(r'$\ell_0- norm$',labelpad=20,size=20)
plt.title("Frog",pad=15,size=24)
plt.legend(fontsize="14",loc='upper right')
plt.grid()
plt.savefig("frog_defend.png")
plt.show()

print("Trained with",np.round(np.mean(defend_x_coords[6]-standard_x_coords[6]),decimals=2),"l_infinity perturbed images")
print("Trained with",np.round(np.mean(defend_y_coords[6]-standard_y_coords[6]),decimals=2),"l_0 perturbed images")
# Out:
# Trained with 0.15 l_infinity perturbed images
# Trained with 0.16 l_0 perturbed images

# %%
plt.figure(figsize=(8,8))

plt.plot(standard_x_coords[9],standard_y_coords[9],linewidth=2.5,label = "Standard")
plt.plot(defend_x_coords[9],defend_y_coords[9],linewidth=2.5,label = "Defended")

plt.xlim(0,0.6)
plt.ylim(0,0.6)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)
plt.xlabel(r'$\ell_\infty- norm$',labelpad=20,size=20)
plt.ylabel(r'$\ell_0- norm$',labelpad=20,size=20)
plt.title("Truck",pad=15,size=24)
plt.legend(fontsize="14",loc='upper right')
plt.grid()
plt.savefig("truck_defend.png")
plt.show()

print("Trained with",np.round(np.mean(defend_x_coords[9]-standard_x_coords[9]),decimals=2),"l_infinity perturbed images")
print("Trained with",np.round(np.mean(defend_y_coords[9]-standard_y_coords[9]),decimals=2),"l_0 perturbed images")
# Out:
# Trained with 0.21 l_infinity perturbed images
# Trained with 0.14 l_0 perturbed images
